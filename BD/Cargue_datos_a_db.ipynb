# %%
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy as sqlal
import psycopg2
import numpy as np

# %%
datos_dep=pd.read_csv('datos_icfes_por_departamento.csv')
datos_dep
# Out:
#      periodo departamento  codigo_departamento  puntaje_ingles  max_p_ingles  \
# 0      20194    SANTANDER                 68.0       50.995223         100.0
# 1      20142    MAGDALENA                 47.0       46.663418         100.0
# 2      20151         META                 50.0       45.505983          76.0
# 3      20142       VAUPES                 97.0       47.097484          71.0
# 4      20151      GUAINIA                 94.0       44.769231          53.0
# ..       ...          ...                  ...             ...           ...
# 353    20181       BOYACA                 15.0       44.816092          76.0
# 354    20211      CAQUETA                 18.0       41.625000          58.0
# 355    20201    RISARALDA                 66.0       67.760369         100.0
# 356    20181     GUAVIARE                 95.0       44.000000          55.0
# 357    20224          NaN                  NaN       35.000000          35.0
#
# ...

# %%
datos_dep.columns
# Out:
# Index(['periodo', 'departamento', 'codigo_departamento', 'puntaje_ingles',
#        'max_p_ingles', 'min_p_ingles', 'std_ingles', 'puntaje_mate',
#        'max_p_mate', 'min_p_mate', 'std_mate', 'puntaje_soc', 'max_p_soc',
#        'min_p_soc', 'std_soc', 'puntaje_nat', 'max_p_nat', 'min_p_nat',
#        'std_nat', 'puntaje_lec', 'max_p_lec', 'min_p_lec', 'std_lec',
#        'puntaje_global', 'max_p_global', 'min_p_global', 'std_global'],
#       dtype='object')

# %%
#Redondeamos los valores extraidos de ATHENA

# %%
datos_dep[['puntaje_ingles','max_p_ingles', 'min_p_ingles', 'std_ingles', 'puntaje_mate',
       'max_p_mate', 'min_p_mate', 'std_mate', 'puntaje_soc', 'max_p_soc',
       'min_p_soc', 'std_soc', 'puntaje_nat', 'max_p_nat', 'min_p_nat',
       'std_nat', 'puntaje_lec', 'max_p_lec', 'min_p_lec', 'std_lec',
       'puntaje_global', 'max_p_global', 'min_p_global', 'std_global']]=datos_dep[['puntaje_ingles','max_p_ingles', 'min_p_ingles', 'std_ingles', 'puntaje_mate',
       'max_p_mate', 'min_p_mate', 'std_mate', 'puntaje_soc', 'max_p_soc',
       'min_p_soc', 'std_soc', 'puntaje_nat', 'max_p_nat', 'min_p_nat',
       'std_nat', 'puntaje_lec', 'max_p_lec', 'min_p_lec', 'std_lec',
       'puntaje_global', 'max_p_global', 'min_p_global', 'std_global']].apply(np.round)

# %%
datos_dep
# Out:
#      periodo departamento  codigo_departamento  puntaje_ingles  max_p_ingles  \
# 0      20194    SANTANDER                 68.0            51.0         100.0
# 1      20142    MAGDALENA                 47.0            47.0         100.0
# 2      20151         META                 50.0            46.0          76.0
# 3      20142       VAUPES                 97.0            47.0          71.0
# 4      20151      GUAINIA                 94.0            45.0          53.0
# ..       ...          ...                  ...             ...           ...
# 353    20181       BOYACA                 15.0            45.0          76.0
# 354    20211      CAQUETA                 18.0            42.0          58.0
# 355    20201    RISARALDA                 66.0            68.0         100.0
# 356    20181     GUAVIARE                 95.0            44.0          55.0
# 357    20224          NaN                  NaN            35.0          35.0
#
# ...

# %%
#nos conectamos a la base de datos
engine = create_engine('postgresql://postgres:pablojose@database-isaac-1.ct6dl822v1pj.us-east-1.rds.amazonaws.com:5432/proyecto_3')

# %%
datos_dep.to_sql('datos_departamento', con=engine, if_exists='replace')

# %%
#nos conectamos nuevamente
engine = create_engine('postgresql://postgres:pablojose@database-isaac-1.ct6dl822v1pj.us-east-1.rds.amazonaws.com:5432/proyecto_3')
dbConnection=engine.connect();

# %%
datos=pd.read_sql("SELECT * FROM datos_departamento", dbConnection)
datos=datos.drop(labels="index",axis=1)
datos
# Out:
#      periodo departamento  codigo_departamento  puntaje_ingles  max_p_ingles  \
# 0      20194    SANTANDER                 68.0            51.0         100.0
# 1      20142    MAGDALENA                 47.0            47.0         100.0
# 2      20151         META                 50.0            46.0          76.0
# 3      20142       VAUPES                 97.0            47.0          71.0
# 4      20151      GUAINIA                 94.0            45.0          53.0
# ..       ...          ...                  ...             ...           ...
# 353    20181       BOYACA                 15.0            45.0          76.0
# 354    20211      CAQUETA                 18.0            42.0          58.0
# 355    20201    RISARALDA                 66.0            68.0         100.0
# 356    20181     GUAVIARE                 95.0            44.0          55.0
# 357    20224         None                  NaN            35.0          35.0
#
# ...

# %%
datos.colums
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 datos.colums
#
# NameError: name 'datos' is not defined
